# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
# %matplotlib inline

# %%
#data_dir='/home/c479r989/research_repo/data-preprocess/ND_MC_Nominal_RHC_testdata'
data_dir='/home/c479r989/research_repo/pv-finder-zak/trainer-model/'

# %%
data_qe_dir=data_dir+'z_model_predictions_qe.csv'
data_res_dir=data_dir+'z_model_predictions_res.csv'
data_dis_dir=data_dir+'z_model_predictions_dis.csv'
data_cc_dir=data_dir+'z_model_predictions_cc.csv'
data_nc_dir=data_dir+'z_model_predictions_nc.csv'

# %%
reco_qe_dir=data_dir+'z_reco_qe.csv'
reco_res_dir=data_dir+'z_reco_res.csv'
reco_dis_dir=data_dir+'z_reco_dis.csv'
reco_cc_dir=data_dir+'z_reco_cc.csv'
reco_nc_dir=data_dir+'z_reco_nc.csv'

# %%
reco_qe=pd.read_csv(reco_qe_dir,header=None)
reco_qe.columns=['True Z','Reco Z']
reco_res=pd.read_csv(reco_res_dir,header=None)
reco_res.columns=['True Z','Reco Z']
reco_dis=pd.read_csv(reco_dis_dir,header=None)
reco_dis.columns=['True Z','Reco Z']
reco_cc=pd.read_csv(reco_cc_dir,header=None)
reco_cc.columns=['True Z','Reco Z']
reco_nc=pd.read_csv(reco_nc_dir,header=None)
reco_nc.columns=['True Z','Reco Z']
reco_full=pd.concat([reco_cc,reco_nc],axis=0)
reco_full.columns=['True Z','Reco Z']

# %%
data_qe=pd.read_csv(data_qe_dir,header=None)
data_qe.columns=['True Z','Model Predictions','Reco Z']
data_res=pd.read_csv(data_res_dir,header=None)
data_res.columns=['True Z','Model Predictions','Reco Z']
data_dis=pd.read_csv(data_dis_dir,header=None)
data_dis.columns=['True Z','Model Predictions','Reco Z']
data_cc=pd.read_csv(data_cc_dir,header=None)
data_cc.columns=['True Z','Model Predictions','Reco Z']
data_nc=pd.read_csv(data_nc_dir,header=None)
data_nc.columns=['True Z','Model Predictions','Reco Z']
data_full=pd.concat([data_cc,data_nc],axis=0)
data_full.columns=['True Z','Model Predictions','Reco Z']

# %%
#Plot Data
#Density Plots

# %%
#quasi-elastic
plt.figure(figsize=(8,8))
true_vertex=data_qe['True Z']
plt.xlabel('True Z Vertex (cm)')
plt.ylabel('Model Z Vertex (cm)')
sns.kdeplot(data=data_qe,x='True Z',y='Model Predictions',fill=True)
plt.ylim(0,1600)
plt.xlim(0,1600)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_qe)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_qe**2))
print(rmsx)
print(averagex)
# Out:
# True Z               494.133210
# Model Predictions    484.719986
# Reco Z               576.932162
# dtype: float64
# True Z               407.786459
# Model Predictions    391.908216
# Reco Z               481.313993
# dtype: float64

# %%
#resonance
plt.figure(figsize=(8,8))
true_vertex=data_res['True Z']
plt.xlabel('True Z Vertex (cm)')
plt.ylabel('Model Z Vertex (cm)')
sns.kdeplot(data=data_res,x='True Z',y='Model Predictions',fill=True)
plt.ylim(0,1600)
plt.xlim(0,1600)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_res)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_res**2))
print(rmsx)
print(averagex)
# Out:
# True Z               618.510292
# Model Predictions    597.593861
# Reco Z               577.791756
# dtype: float64
# True Z               532.605653
# Model Predictions    515.871930
# Reco Z               481.076263
# dtype: float64

# %%
#deep ineleastic scattering
plt.figure(figsize=(8,8))
true_vertex=data_dis['True Z']
plt.xlabel('True Z Vertex (cm)')
plt.ylabel('Model Z Vertex (cm)')
sns.kdeplot(data=data_dis,x='True Z',y='Model Predictions',fill=True)
plt.ylim(0,1600)
plt.xlim(0,1600)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_dis)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_dis**2))
print(rmsx)
print(averagex)
# Out:
# True Z               594.115172
# Model Predictions    576.676168
# Reco Z               573.622937
# dtype: float64
# True Z               514.635992
# Model Predictions    503.600102
# Reco Z               477.014931
# dtype: float64

# %%
#cc
plt.figure(figsize=(8,8))
true_vertex=data_cc['True Z']
plt.xlabel('True Z Vertex (cm)')
plt.ylabel('Model Z Vertex (cm)')
sns.kdeplot(data=data_cc,x='True Z',y='Model Predictions',fill=True)
plt.ylim(0,1600)
plt.xlim(0,1600)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_cc)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_cc**2))
print(rmsx)
print(averagex)
# Out:
# True Z               502.265156
# Model Predictions    492.409604
# Reco Z               576.587831
# dtype: float64
# True Z               423.146018
# Model Predictions    414.326965
# Reco Z               480.322794
# dtype: float64

# %%
#nc
plt.figure(figsize=(8,8))
true_vertex=data_nc['True Z']
plt.xlabel('True Z Vertex (cm)')
plt.ylabel('Model Z Vertex (cm)')
sns.kdeplot(data=data_nc,x='True Z',y='Model Predictions',fill=True)
plt.ylim(0,1600)
plt.xlim(0,1600)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_nc)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_nc**2))
print(rmsx)
print(averagex)
# Out:
# True Z               656.853394
# Model Predictions    632.933702
# Reco Z               577.471389
# dtype: float64
# True Z               574.564007
# Model Predictions    554.495813
# Reco Z               480.286239
# dtype: float64

# %%
#full
plt.figure(figsize=(8,8))
true_vertex=data_full['True Z']
plt.xlabel('True Z Vertex (cm)')
plt.ylabel('Model Z Vertex (cm)')
sns.kdeplot(data=data_full,x='True Z',y='Model Predictions',fill=True)
plt.ylim(0,1600)
plt.xlim(0,1600)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_full)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_full**2))
print(rmsx)
print(averagex)
# Out:
# True Z               581.328206
# Model Predictions    563.982145
# Reco Z               577.010442
# dtype: float64
# True Z               495.541768
# Model Predictions    481.344292
# Reco Z               480.305317
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.rcParams.update(('font.size: 17'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ed24344ee5f7> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.rcParams.update(('font.size: 17'))
#
# /opt/software/software/Python/3.7.4-GCCcore-8.3.0/lib/python3.7/_collections_abc.py in update(*args, **kwds)
#     844                     self[key] = other[key]
#     845             else:
# --> 846                 for key, value in other:
#     847                     self[key] = value
#     848         for key, value in kwds.items():
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
#quasi elastic
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_qe['True Z']
true_reco_vertex=reco_qe['True Z'][:len(data_qe)]
sns.kdeplot(data=data_qe, x='True Z', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_qe[:len(data_qe)], x='True Z', y='Reco Z',fill=True,ax=ax[1])

ax[0].set(xlabel='True Z Vertex (cm)',ylabel='Model Z Vertex (cm)')
ax[1].set(xlabel='True Z Vertex (cm)',ylabel='Reco Z Vertex (cm)')

ax[0].set_ylim(0,1600)
ax[0].set_xlim(0,1600)

ax[1].set_ylim(0,1600)
ax[1].set_xlim(0,1600)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('z-qes-modelpred-true-vs-reco-kde.pdf')
plt.savefig('z-qes-modelpred-true-vs-reco-kde.png',dpi=600)

# %%
#resonance
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_res['True Z']
true_reco_vertex=reco_res['True Z'][:len(data_qe)]
sns.kdeplot(data=data_res, x='True Z', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_res[:len(data_qe)], x='True Z', y='Reco Z',fill=True,ax=ax[1])

ax[0].set(xlabel='True Z Vertex (cm)',ylabel='Model Z Vertex (cm)')
ax[1].set(xlabel='True Z Vertex (cm)',ylabel='Reco Z Vertex (cm)')

ax[0].set_ylim(0,1600)
ax[0].set_xlim(0,1600)

ax[1].set_ylim(0,1600)
ax[1].set_xlim(0,1600)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('z-res-modelpred-true-vs-reco-kde.pdf')
plt.savefig('z-res-modelpred-true-vs-reco-kde.png',dpi=600)

# %%
#deep inelastic scattering
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_dis['True Z']
true_reco_vertex=reco_dis['True Z'][:len(data_qe)]
sns.kdeplot(data=data_dis, x='True Z', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_dis[:len(data_qe)], x='True Z', y='Reco Z',fill=True,ax=ax[1])

ax[0].set(xlabel='True Z Vertex (cm)',ylabel='Model Z Vertex (cm)')
ax[1].set(xlabel='True Z Vertex (cm)',ylabel='Reco Z Vertex (cm)')

ax[0].set_ylim(0,1600)
ax[0].set_xlim(0,1600)

ax[1].set_ylim(0,1600)
ax[1].set_xlim(0,1600)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('z-dis-modelpred-true-vs-reco-kde.pdf')
plt.savefig('z-dis-modelpred-true-vs-reco-kde.png',dpi=600)

# %%
#cc
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_cc['True Z']
true_reco_vertex=reco_cc['True Z'][:len(data_qe)]
sns.kdeplot(data=data_cc, x='True Z', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_cc[:len(data_qe)], x='True Z', y='Reco Z',fill=True,ax=ax[1])

ax[0].set(xlabel='True Z Vertex (cm)',ylabel='Model Z Vertex (cm)')
ax[1].set(xlabel='True Z Vertex (cm)',ylabel='Reco Z Vertex (cm)')

ax[0].set_ylim(0,1600)
ax[0].set_xlim(0,1600)

ax[1].set_ylim(0,1600)
ax[1].set_xlim(0,1600)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('z-cc-modelpred-true-vs-reco-kde.pdf')
plt.savefig('z-cc-modelpred-true-vs-reco-kde.png',dpi=600)

# %%
#nc
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_nc['True Z']
true_reco_vertex=reco_nc['True Z'][:len(data_qe)]
sns.kdeplot(data=data_nc, x='True Z', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_nc[:len(data_qe)], x='True Z', y='Reco Z',fill=True,ax=ax[1])

ax[0].set(xlabel='True Z Vertex (cm)',ylabel='Model Z Vertex (cm)')
ax[1].set(xlabel='True Z Vertex (cm)',ylabel='Reco Z Vertex (cm)')

ax[0].set_ylim(0,1600)
ax[0].set_xlim(0,1600)

ax[1].set_ylim(0,1600)
ax[1].set_xlim(0,1600)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('z-nc-modelpred-true-vs-reco-kde.pdf')
plt.savefig('z-nc-modelpred-true-vs-reco-kde.png',dpi=600)

# %%
#full
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_full['True Z']
true_reco_vertex=reco_full['True Z'][:len(data_qe)]
sns.kdeplot(data=data_full, x='True Z', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_full[:len(data_qe)], x='True Z', y='Reco Z',fill=True,ax=ax[1])

ax[0].set(xlabel='True Z Vertex (cm)',ylabel='Model Z Vertex (cm)')
ax[1].set(xlabel='True Z Vertex (cm)',ylabel='Reco Z Vertex (cm)')

ax[0].set_ylim(0,1600)
ax[0].set_xlim(0,1600)

ax[1].set_ylim(0,1600)
ax[1].set_xlim(0,1600)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('z-full-modelpred-true-vs-reco-kde.pdf')
plt.savefig('z-full-modelpred-true-vs-reco-kde.png',dpi=600)

# %%
# Spread comparison between reconstruction methods


# test before sending to csv
#diff_reco=true_reco_vertex - true_vertex
diff_reco=reco_qe[:len(data_qe)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')
#sns.displot(true_vertex)
#sns.displot(diff_reco)
#plt.plot(x_values, y_values.pdf(x_values))

plt.ylim(0, 3500)
plt.xlim(-300, 300)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-83216c284c32> in <module>
#       4 # test before sending to csv
#       5 #diff_reco=true_reco_vertex - true_vertex
# ----> 6 diff_reco=reco_qe[:len(data_qe)]
#       7 plt.figure(figsize=(12,8))
#       8 sns.displot(diff_reco,color='k')
#
# NameError: name 'reco_qe' is not defined

# %%
# Spread comparison between reconstruction methods
#diff_reco=reco_qe[:len(reco_qe)]

#Switch to model predictions (new data) by uncommenting below
diff_reco=data_qe[:len(data_qe)]

plt.figure(figsize=(12,8))
sns.displot(diff_reco)
            
plt.ylim(0, 1000)
plt.xlim(0, 1500)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(15.364166666666662, 0.5, 'Count')

# %%
#res
#diff_reco=reco_res[:len(data_res)]
#Switch to reco data by uncommenting below
diff_reco=data_res[:len(data_res)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 2000)
plt.xlim(0, 1500)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(8.989166666666662, 0.5, 'Count')

# %%
#dis
#diff_reco=reco_dis[:len(data_dis)]
#Switch to reco data by uncommenting below
diff_reco=data_dis[:len(data_dis)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 2000)
plt.xlim(0, 1500)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(8.989166666666662, 0.5, 'Count')

# %%
#nc
#diff_reco=reco_nc[:len(data_nc)]
#Switch to reco data by uncommenting below
diff_reco=data_nc[:len(data_nc)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 2000)
plt.xlim(0, 1500)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(8.989166666666662, 0.5, 'Count')

# %%
#cc
#diff_reco=reco_cc[:len(data_cc)]
#Switch to reco data by uncommenting below
diff_reco=data_cc[:len(data_cc)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 2000)
plt.xlim(0, 1500)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(8.989166666666662, 0.5, 'Count')

# %%
#full
#diff_reco=reco_full[:len(data_full)]
#Switch to reco data by uncommenting below
diff_reco=data_full[:len(data_full)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 3500)
plt.xlim(0, 1500)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(8.989166666666662, 0.5, 'Count')
