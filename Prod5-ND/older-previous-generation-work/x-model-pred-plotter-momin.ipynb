# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
# %matplotlib inline

# %%
data_dir='/home/c479r989/research_repo/pv-finder-zak/trainer-model/'
#data_dir='/home/c479r989/research_repo/pv-finder-zak/trainer-model/'

# %%
data_qe_dir=data_dir+'x_model_predictions_qe.csv'
data_res_dir=data_dir+'x_model_predictions_res.csv'
data_dis_dir=data_dir+'x_model_predictions_dis.csv'
data_cc_dir=data_dir+'x_model_predictions_cc.csv'
data_nc_dir=data_dir+'x_model_predictions_nc.csv'

# %%
reco_qe_dir=data_dir+'x_reco_qe.csv'
reco_res_dir=data_dir+'x_reco_res.csv'
reco_dis_dir=data_dir+'x_reco_dis.csv'
reco_cc_dir=data_dir+'x_reco_cc.csv'
reco_nc_dir=data_dir+'x_reco_nc.csv'

# %%
reco_qe=pd.read_csv(reco_qe_dir,header=None)
reco_qe.columns=['True X','Reco X']
reco_res=pd.read_csv(reco_res_dir,header=None)
reco_res.columns=['True X','Reco X']
reco_dis=pd.read_csv(reco_dis_dir,header=None)
reco_dis.columns=['True X','Reco X']
reco_cc=pd.read_csv(reco_cc_dir,header=None)
reco_cc.columns=['True X','Reco X']
reco_nc=pd.read_csv(reco_nc_dir,header=None)
reco_nc.columns=['True X','Reco X']
reco_full=pd.concat([reco_cc,reco_nc],axis=0)
reco_full.columns=['True X','Reco X']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f647fe6d265e> in <module>
#       1 reco_qe=pd.read_csv(reco_qe_dir,header=None)
# ----> 2 reco_qe.columns=['True X','Reco X']
#       3 reco_res=pd.read_csv(reco_res_dir,header=None)
#       4 reco_res.columns=['True X','Reco X']
#       5 reco_dis=pd.read_csv(reco_dis_dir,header=None)
#
# /opt/software/software/SciPy-bundle/2019.10-foss-2019b-Python-3.7.4/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
data_qe=pd.read_csv(data_qe_dir,header=None)
data_qe.columns=['True X','Model Predictions','Reco X']
data_res=pd.read_csv(data_res_dir,header=None)
data_res.columns=['True X','Model Predictions','Reco X']
data_dis=pd.read_csv(data_dis_dir,header=None)
data_dis.columns=['True X','Model Predictions','Reco X']
data_cc=pd.read_csv(data_cc_dir,header=None)
data_cc.columns=['True X','Model Predictions','Reco X']
data_nc=pd.read_csv(data_nc_dir,header=None)
data_nc.columns=['True X','Model Predictions','Reco X']
data_full=pd.concat([data_cc,data_nc],axis=0)
data_full.columns=['True X','Model Predictions','Reco X']

# %%
import csv
f=data_qe
f.columns
#list(f['Reco X'])

#file=open(reco_qe_dir)
#csvreader = csv.reader(file)
#header = next(csvreader)
#print(header)
#file.close()
#print(reco_qe)

import pandas as pd
data= pd.read_csv("x_model_predictions_qe.csv")
data
# Out:
#        -1.155740356445312500e+02  -1.167814254760742188e+02  \
# 0                     139.634262                 140.529373
# 1                      -5.762777                  -6.058037
# 2                      67.141068                  64.867393
# 3                      44.829762                  35.424969
# 4                     127.507614                  71.880051
# ...                          ...                        ...
# 12982                  58.413898                  48.040070
# 12983                 121.621063                 114.950050
# 12984                  -7.883763                 -98.031845
# 12985                 -54.749660                 -48.360981
# 12986                        NaN                        NaN
#
#        -1.064501495361328125e+02
# 0                    -120.295090
# 1                    -116.616508
# 2                      64.026520
# 3                    -132.404327
# 4                     106.044258
# ...                          ...
# ...

# %% [markdown]
# #Plot Data
# #Density Plots

# %%
#quasi-elastic
plt.figure(figsize=(8,8))
true_vertex=data_qe['True X']
plt.xlabel('True X Vertex (cm)')
plt.ylabel('Model X Vertex (cm)')
sns.kdeplot(data=data_qe,x='True X',y='Model Predictions',fill=True)
plt.ylim(-250,250)
plt.xlim(-250,250)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_qe)
#print("The mean is" , averagex)

#Calculating RMS
rmsx=np.sqrt(np.mean(data_qe**2))
#print("The RMS is " , rmsx)

# %%
print(averagex)
print(rmsx)
#reco_qe.keys()
# Out:
# True X               -4.032438
# Model Predictions    -8.228992
# Reco X              -11.611389
# dtype: float64
# True X               88.991443
# Model Predictions    94.527124
# Reco X               88.710836
# dtype: float64

# %%
#resonance
plt.figure(figsize=(8,8))
true_vertex=data_res['True X']
plt.xlabel('True X Vertex (cm)')
plt.ylabel('Model X Vertex (cm)')
sns.kdeplot(data=data_res,x='True X',y='Model Predictions',fill=True)
plt.ylim(-250,250)
plt.xlim(-250,250)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_res)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_res**2))
print(rmsx)
print(averagex)
# Out:
# True X               83.296286
# Model Predictions    90.229551
# Reco X               88.458123
# dtype: float64
# True X               -9.692310
# Model Predictions   -14.658655
# Reco X              -11.708168
# dtype: float64

# %%
#deep ineleastic scattering
plt.figure(figsize=(8,8))
true_vertex=data_dis['True X']
plt.xlabel('True X Vertex (cm)')
plt.ylabel('Model X Vertex (cm)')
sns.kdeplot(data=data_dis,x='True X',y='Model Predictions',fill=True)
plt.ylim(-250,250)
plt.xlim(-250,250)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_dis)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_dis**2))
print(rmsx)
print(averagex)
# Out:
# True X               81.335199
# Model Predictions    84.044554
# Reco X               88.914420
# dtype: float64
# True X               -9.633202
# Model Predictions   -12.219268
# Reco X              -13.009131
# dtype: float64

# %%
#cc
plt.figure(figsize=(8,8))
true_vertex=data_cc['True X']
plt.xlabel('True X Vertex (cm)')
plt.ylabel('Model X Vertex (cm)')
sns.kdeplot(data=data_cc,x='True X',y='Model Predictions',fill=True)
plt.ylim(-250,250)
plt.xlim(-250,250)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_cc)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_cc**2))
print(rmsx)
print(averagex)
# Out:
# True X               85.085590
# Model Predictions    85.974789
# Reco X               88.434270
# dtype: float64
# True X               -5.932614
# Model Predictions    -8.247557
# Reco X              -11.607173
# dtype: float64

# %%
#nc
plt.figure(figsize=(8,8))
true_vertex=data_nc['True X']
plt.xlabel('True X Vertex (cm)')
plt.ylabel('Model X Vertex (cm)')
sns.kdeplot(data=data_nc,x='True X',y='Model Predictions',fill=True)
plt.ylim(-250,250)
plt.xlim(-250,250)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_nc)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_nc**2))
print(rmsx)
print(averagex)
# Out:
# True X               82.855452
# Model Predictions    92.227722
# Reco X               88.933046
# dtype: float64
# True X              -11.297779
# Model Predictions   -17.031414
# Reco X              -12.346861
# dtype: float64

# %%
#full
plt.figure(figsize=(8,8))
true_vertex=data_full['True X']
plt.xlabel('True X Vertex (cm)')
plt.ylabel('Model X Vertex (cm)')
sns.kdeplot(data=data_full,x='True X',y='Model Predictions',fill=True)
plt.ylim(-250,250)
plt.xlim(-250,250)
plt.plot(true_vertex,true_vertex,'r',lw=1.0,ls='--')

#calculating mean and stuff
averagex=np.mean(data_full)
#Calculating RMS
rmsx=np.sqrt(np.mean(data_full**2))
print(rmsx)
print(averagex)
# Out:
# True X               84.026705
# Model Predictions    89.019247
# Reco X               88.673092
# dtype: float64
# True X               -8.497799
# Model Predictions   -12.447282
# Reco X              -11.960829
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.rcParams.update(('font.size: 17'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ed24344ee5f7> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.rcParams.update(('font.size: 17'))
#
# /opt/software/software/Python/3.7.4-GCCcore-8.3.0/lib/python3.7/_collections_abc.py in update(*args, **kwds)
#     844                     self[key] = other[key]
#     845             else:
# --> 846                 for key, value in other:
#     847                     self[key] = value
#     848         for key, value in kwds.items():
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
#quasi elastic
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_qe['True X']
true_reco_vertex=reco_qe['True X'][:len(data_qe)]
sns.kdeplot(data=data_qe, x='True X', y='Model Predictions', fill=True,ax=ax[0])
#sns.kdeplot(data=reco_qe[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])

ax[0].set(xlabel='True X Vertex (cm)',ylabel='Model X Vertex (cm)')
ax[1].set(xlabel='True X Vertex (cm)',ylabel='Reco X Vertex (cm)')

ax[0].set_ylim(-200,200)
ax[0].set_xlim(-200,200)

ax[1].set_ylim(-200,200)
ax[1].set_xlim(-200,200)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('x-qes-modelpred-true-vs-reco-kde.pdf')
plt.savefig('x-qes-modelpred-true-vs-reco-kde.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/software/software/SciPy-bundle/2019.10-fosscuda-2019b-Python-3.7.4/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'True X'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-fbdb4ebf802b> in <module>
#       2 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
# ...

# %%
#resonance
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_res['True X']
true_reco_vertex=reco_res['True X'][:len(data_qe)]
sns.kdeplot(data=data_res, x='True X', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_res[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])

ax[0].set(xlabel='True X Vertex (cm)',ylabel='Model X Vertex (cm)')
ax[1].set(xlabel='True X Vertex (cm)',ylabel='Reco X Vertex (cm)')

ax[0].set_ylim(-200,200)
ax[0].set_xlim(-200,200)

ax[1].set_ylim(-200,200)
ax[1].set_xlim(-200,200)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('x-res-modelpred-true-vs-reco-kde.pdf')
plt.savefig('x-res-modelpred-true-vs-reco-kde.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-881df76ecde7> in <module>
#       2 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
#       3 true_vertex=data_res['True X']
# ----> 4 true_reco_vertex=reco_res['True X'][:len(data_qe)]
#       5 sns.kdeplot(data=data_res, x='True X', y='Model Predictions', fill=True,ax=ax[0])
#       6 sns.kdeplot(data=reco_res[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
#
# NameError: name 'reco_res' is not defined

# %%
#deep inelastic scattering
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_dis['True X']
true_reco_vertex=reco_dis['True X'][:len(data_qe)]
sns.kdeplot(data=data_dis, x='True X', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_dis[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])

ax[0].set(xlabel='True X Vertex (cm)',ylabel='Model X Vertex (cm)')
ax[1].set(xlabel='True X Vertex (cm)',ylabel='Reco X Vertex (cm)')

ax[0].set_ylim(-200,200)
ax[0].set_xlim(-200,200)

ax[1].set_ylim(-200,200)
ax[1].set_xlim(-200,200)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('x-dis-modelpred-true-vs-reco-kde.pdf')
plt.savefig('x-dis-modelpred-true-vs-reco-kde.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-38e8ab3f6e23> in <module>
#       2 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
#       3 true_vertex=data_dis['True X']
# ----> 4 true_reco_vertex=reco_dis['True X'][:len(data_qe)]
#       5 sns.kdeplot(data=data_dis, x='True X', y='Model Predictions', fill=True,ax=ax[0])
#       6 sns.kdeplot(data=reco_dis[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
#
# NameError: name 'reco_dis' is not defined

# %%
#cc
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_cc['True X']
true_reco_vertex=reco_cc['True X'][:len(data_qe)]
sns.kdeplot(data=data_cc, x='True X', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_cc[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])

ax[0].set(xlabel='True X Vertex (cm)',ylabel='Model X Vertex (cm)')
ax[1].set(xlabel='True X Vertex (cm)',ylabel='Reco X Vertex (cm)')

ax[0].set_ylim(-200,200)
ax[0].set_xlim(-200,200)

ax[1].set_ylim(-200,200)
ax[1].set_xlim(-200,200)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('x-cc-modelpred-true-vs-reco-kde.pdf')
plt.savefig('x-cc-modelpred-true-vs-reco-kde.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-dec159c0f2ab> in <module>
#       2 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
#       3 true_vertex=data_cc['True X']
# ----> 4 true_reco_vertex=reco_cc['True X'][:len(data_qe)]
#       5 sns.kdeplot(data=data_cc, x='True X', y='Model Predictions', fill=True,ax=ax[0])
#       6 sns.kdeplot(data=reco_cc[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
#
# NameError: name 'reco_cc' is not defined

# %%
#nc
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_nc['True X']
true_reco_vertex=reco_nc['True X'][:len(data_qe)]
sns.kdeplot(data=data_nc, x='True X', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_nc[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])

ax[0].set(xlabel='True X Vertex (cm)',ylabel='Model X Vertex (cm)')
ax[1].set(xlabel='True X Vertex (cm)',ylabel='Reco X Vertex (cm)')

ax[0].set_ylim(-200,200)
ax[0].set_xlim(-200,200)

ax[1].set_ylim(-200,200)
ax[1].set_xlim(-200,200)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('x-nc-modelpred-true-vs-reco-kde.pdf')
plt.savefig('x-nc-modelpred-true-vs-reco-kde.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-2de8ce1b5b49> in <module>
#       2 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
#       3 true_vertex=data_nc['True X']
# ----> 4 true_reco_vertex=reco_nc['True X'][:len(data_qe)]
#       5 sns.kdeplot(data=data_nc, x='True X', y='Model Predictions', fill=True,ax=ax[0])
#       6 sns.kdeplot(data=reco_nc[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
#
# NameError: name 'reco_nc' is not defined

# %%
#full
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
true_vertex=data_full['True X']
true_reco_vertex=reco_full['True X'][:len(data_qe)]
sns.kdeplot(data=data_full, x='True X', y='Model Predictions', fill=True,ax=ax[0])
sns.kdeplot(data=reco_full[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])

ax[0].set(xlabel='True X Vertex (cm)',ylabel='Model X Vertex (cm)')
ax[1].set(xlabel='True X Vertex (cm)',ylabel='Reco X Vertex (cm)')

ax[0].set_ylim(-200,200)
ax[0].set_xlim(-200,200)

ax[1].set_ylim(-200,200)
ax[1].set_xlim(-200,200)

ax[0].plot(true_vertex,true_vertex,'r',lw=1.5,ls='--')
ax[1].plot(true_reco_vertex,true_reco_vertex,'r',lw=1.5,ls='--')
plt.savefig('x-full-modelpred-true-vs-reco-kde.pdf')
plt.savefig('x-full-modelpred-true-vs-reco-kde.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-21ddfcd353ad> in <module>
#       2 fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
#       3 true_vertex=data_full['True X']
# ----> 4 true_reco_vertex=reco_full['True X'][:len(data_qe)]
#       5 sns.kdeplot(data=data_full, x='True X', y='Model Predictions', fill=True,ax=ax[0])
#       6 sns.kdeplot(data=reco_full[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
#
# NameError: name 'reco_full' is not defined

# %%
# Spread comparison between reconstruction methods
#diff_reco=reco_qe[:len(reco_qe)]

#Switch to model predictions (new data) by uncommenting below
diff_reco=data_qe[:len(data_qe)]

plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')
#sns.displot(reco_qe[:len(reco_qe)])
sns.displot(reco_qe)

plt.ylim(0, 1000)
plt.xlim(-200, 200)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# Text(7.653541666666662, 0.5, 'Count')

# %%
# %matplotlib inline
sns.kdeplot(data=reco_qe[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-97e186a09f93> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 sns.kdeplot(data=reco_qe[:len(data_qe)], x='True X', y='Reco X',fill=True,ax=ax[1])
#
# ~/.local/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.local/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
# ...

# %%
#res
diff_reco=reco_res[:len(data_res)]

#Switch to reco data by uncommenting below
diff_reco=data_res[:len(data_res)]

plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 3500)
plt.xlim(-300, 300)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-67206d67c839> in <module>
#       1 #res
# ----> 2 diff_reco=reco_res[:len(data_res)]
#       3
#       4 #Switch to reco data by uncommenting below
#       5 diff_reco=data_res[:len(data_res)]
#
# NameError: name 'reco_res' is not defined

# %%
#dis
diff_reco=reco_dis[:len(data_dis)]
#Switch to reco data by uncommenting below
#diff_reco=data_dis[:len(data_dis)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 3500)
plt.xlim(-300, 300)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-57717154876b> in <module>
#       1 #dis
# ----> 2 diff_reco=reco_dis[:len(data_dis)]
#       3 #Switch to reco data by uncommenting below
#       4 #diff_reco=data_dis[:len(data_dis)]
#       5 plt.figure(figsize=(12,8))
#
# NameError: name 'reco_dis' is not defined

# %%
#cc

diff_reco=reco_cc[:len(data_cc)]
#Switch to reco data by uncommenting below
#diff_reco=data_cc[:len(data_cc)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 3500)
plt.xlim(-300, 300)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-cc92fe032d82> in <module>
#       1 #cc
#       2
# ----> 3 diff_reco=reco_cc[:len(data_cc)]
#       4 #Switch to reco data by uncommenting below
#       5 #diff_reco=data_cc[:len(data_cc)]
#
# NameError: name 'reco_cc' is not defined

# %%
#nc

diff_reco=reco_nc[:len(data_nc)]
#Switch to reco data by uncommenting below
#diff_reco=data_nc[:len(data_nc)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 3500)
plt.xlim(-300, 300)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e16e88213976> in <module>
#       1 #nc
#       2
# ----> 3 diff_reco=reco_nc[:len(data_nc)]
#       4 #Switch to reco data by uncommenting below
#       5 #diff_reco=data_nc[:len(data_nc)]
#
# NameError: name 'reco_nc' is not defined

# %%
#full
diff_reco=reco_full[:len(data_full)]
#Switch to reco data by uncommenting below
#diff_reco=data_full[:len(data_full)]
plt.figure(figsize=(12,8))
sns.displot(diff_reco,color='k')

plt.ylim(0, 3500)
plt.xlim(-300, 300)

plt.xlabel('Detector Length (cm)')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-40207bdfcea1> in <module>
#       1 #full
# ----> 2 diff_reco=reco_full[:len(data_full)]
#       3 #Switch to reco data by uncommenting below
#       4 #diff_reco=data_full[:len(data_full)]
#       5 plt.figure(figsize=(12,8))
#
# NameError: name 'reco_full' is not defined

# %%
import os
import sys
import time
import math
import numpy
import warnings
import struct
import binascii
import pandas as pd
import numpy as np
import pickle
import h5py
import tensorflow as tf
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
# %matplotlib inline

# %%
from datetime import datetime
from sklearn import preprocessing
from tqdm import tqdm,tqdm_notebook
from IPython.display import display, clear_output
from matplotlib.image import imread # read images
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KernelDensity
from scipy.signal import find_peaks
from numpy.polynomial.polynomial import polyfit
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Activation,concatenate
from tensorflow.keras.optimizers import Adam #optimizer
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
from tensorflow.python.client import device_lib
from sklearn.preprocessing import MinMaxScaler # normalize and scale data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score,r2_score

# %%
f=h5py.File(reco_qe_dir)
f.keys()
# Out:
# /opt/software/software/IPython/7.9.0-foss-2019b-Python-3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/software/software/h5py/2.10.0-foss-2019b-Python-3.7.4/lib/python3.7/site-packages/h5py-2.10.0-py3.7-linux-x86_64.egg/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     198         try:
# --> 199             fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     200         except IOError:
# ...

# %%
print(data_qe)
# Out:
#            True X  Model Predictions      Reco X
# 0     -115.574036        -117.790337 -106.450150
# 1      139.634262         137.604507 -120.295090
# 2       -5.762777          -7.517517 -116.616508
# 3       67.141068          71.280540   64.026520
# 4       44.829762          42.488747 -132.404327
# ...           ...                ...         ...
# 12983   58.413898          69.276047   -7.347905
# 12984  121.621063         118.663788    4.245920
# 12985   -7.883763         132.761475  -96.836227
# 12986  -54.749660         -36.327831   21.378353
# 12987         NaN                NaN  -44.419003
#
# [12988 rows x 3 columns]

# %%
data_qe.keys()
# Out:
# Index(['True X', 'Model Predictions', 'Reco X'], dtype='object')
